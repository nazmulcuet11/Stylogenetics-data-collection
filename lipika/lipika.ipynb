# %%
import os
from urllib.request import urlopen
from bs4 import BeautifulSoup

# %%
url = 'https://rabindra-rachanabali.nltr.org/node/4?subcatid=7&catId=5'
page = urlopen(url)
soup = BeautifulSoup(page, 'lxml')

# %%
links = {}
anchors = soup.find('table', {'class': 'list'}).find_all('a')
for anchor in anchors:
    links[anchor.text] = anchor['href']

# %%
len(links)
# Out:
# 39

# %%
base_url = 'https://rabindra-rachanabali.nltr.org'
for key in links.keys():
    #temporary code to avoid crolling existing file
    file_path = os.getcwd() + '/' + key + '.txt'
    if os.path.exists(file_path):
        print('exists')
        continue
    #end of temporary code
    
    print('start crolling: ' + key)
    url = base_url + links[key]
    print(url)
    text = ""
    file_name = key + '.txt'
    while True:
        page = urlopen(url)
        soup = BeautifulSoup(page, 'html.parser')
        div = soup.find('div', attrs={'class': 'upanyas'})
        if not div:
            div = soup.find('div', attrs={'class': 'node'})
        text += div.text
        # fetch next page
        right_navigation = soup.find('div', {'id': 'rightnavigation'})
        if right_navigation:
            next_page_link = right_navigation.a['href']
            url = base_url + next_page_link
            print(url)
        else:
            print('end of the story')
            break
    #end of while
    f = open(file_name,'w')
    f.write(text)
    f.close()
#end of for
# Out:
# start crolling: আগমনী
# https://rabindra-rachanabali.nltr.org/node/1483
# https://rabindra-rachanabali.nltr.org/node/1491
# https://rabindra-rachanabali.nltr.org/node/1629
# https://rabindra-rachanabali.nltr.org/node/1630
# end of the story
# start crolling: একটি চাউনি
# https://rabindra-rachanabali.nltr.org/node/1307
# end of the story
# start crolling: প্রথম চিঠি
# https://rabindra-rachanabali.nltr.org/node/1454
# https://rabindra-rachanabali.nltr.org/node/1608
# end of the story
# start crolling: তোতা কাহিনী
# https://rabindra-rachanabali.nltr.org/node/1396
# https://rabindra-rachanabali.nltr.org/node/1408
# https://rabindra-rachanabali.nltr.org/node/1595
# end of the story
# start crolling: স্বর্গ - মর্ত
# https://rabindra-rachanabali.nltr.org/node/1506
# https://rabindra-rachanabali.nltr.org/node/1513
# https://rabindra-rachanabali.nltr.org/node/1516
# https://rabindra-rachanabali.nltr.org/node/1523
# https://rabindra-rachanabali.nltr.org/node/1631
# end of the story
# start crolling: মীনু
# https://rabindra-rachanabali.nltr.org/node/1342
# https://rabindra-rachanabali.nltr.org/node/1569
# end of the story
# start crolling: গল্প
# https://rabindra-rachanabali.nltr.org/node/1332
# https://rabindra-rachanabali.nltr.org/node/1566
# end of the story
# start crolling: উপসংহার
# https://rabindra-rachanabali.nltr.org/node/1430
# https://rabindra-rachanabali.nltr.org/node/1602
# end of the story
# start crolling: গলি
# https://rabindra-rachanabali.nltr.org/node/1304
# end of the story
# start crolling: কর্তার ভূত
# https://rabindra-rachanabali.nltr.org/node/1380
# https://rabindra-rachanabali.nltr.org/node/1383
# https://rabindra-rachanabali.nltr.org/node/1592
# end of the story
# start crolling: নামের খেলা
# https://rabindra-rachanabali.nltr.org/node/1346
# https://rabindra-rachanabali.nltr.org/node/1573
# https://rabindra-rachanabali.nltr.org/node/1579
# end of the story
# start crolling: প্রাণমন
# https://rabindra-rachanabali.nltr.org/node/1476
# https://rabindra-rachanabali.nltr.org/node/1479
# https://rabindra-rachanabali.nltr.org/node/1624
# https://rabindra-rachanabali.nltr.org/node/1627
# https://rabindra-rachanabali.nltr.org/node/1628
# end of the story
# start crolling: সন্ধ্যা ও প্রভাত
# https://rabindra-rachanabali.nltr.org/node/1290
# end of the story
# start crolling: ঘোড়া
# https://rabindra-rachanabali.nltr.org/node/1370
# https://rabindra-rachanabali.nltr.org/node/1374
# end of the story
# start crolling: বাঁশি
# https://rabindra-rachanabali.nltr.org/node/1285
# end of the story
# start crolling: সিদ্ধি
# https://rabindra-rachanabali.nltr.org/node/1444
# https://rabindra-rachanabali.nltr.org/node/1446
# https://rabindra-rachanabali.nltr.org/node/1606
# end of the story
# start crolling: মেঘলা দিনে
# https://rabindra-rachanabali.nltr.org/node/1253
# end of the story
# start crolling: প্রথম শোক
# https://rabindra-rachanabali.nltr.org/node/1323
# end of the story
# start crolling: একাটি দিন
# https://rabindra-rachanabali.nltr.org/node/1311
# end of the story
# start crolling: সতেরো বছর
# https://rabindra-rachanabali.nltr.org/node/1319
# end of the story
# start crolling: পায়ে চলার পথ
# https://rabindra-rachanabali.nltr.org/node/1250
# end of the story
# start crolling: ভুল স্বর্গ
# https://rabindra-rachanabali.nltr.org/node/1349
# https://rabindra-rachanabali.nltr.org/node/1582
# https://rabindra-rachanabali.nltr.org/node/1584
# end of the story
# start crolling: পুরোনো বাড়ি
# https://rabindra-rachanabali.nltr.org/node/1300
# https://rabindra-rachanabali.nltr.org/node/1563
# end of the story
# start crolling: সুয়োরানীর সাধ
# https://rabindra-rachanabali.nltr.org/node/1357
# https://rabindra-rachanabali.nltr.org/node/1589
# end of the story
# start crolling: রাজপুত্তুর
# https://rabindra-rachanabali.nltr.org/node/1354
# https://rabindra-rachanabali.nltr.org/node/1586
# end of the story
# start crolling: পরীর পরিচয়
# https://rabindra-rachanabali.nltr.org/node/1468
# https://rabindra-rachanabali.nltr.org/node/1470
# https://rabindra-rachanabali.nltr.org/node/1612
# https://rabindra-rachanabali.nltr.org/node/1622
# end of the story
# start crolling: রথযাত্রা
# https://rabindra-rachanabali.nltr.org/node/1456
# end of the story
# start crolling: সওগাত
# https://rabindra-rachanabali.nltr.org/node/1458
# end of the story
# start crolling: বাণী
# https://rabindra-rachanabali.nltr.org/node/1261
# https://rabindra-rachanabali.nltr.org/node/1545
# end of the story
# start crolling: পট
# https://rabindra-rachanabali.nltr.org/node/1420
# https://rabindra-rachanabali.nltr.org/node/1598
# end of the story
# start crolling: মুক্তি
# https://rabindra-rachanabali.nltr.org/node/1464
# https://rabindra-rachanabali.nltr.org/node/1609
# end of the story
# start crolling: অস্পষ্ট
# https://rabindra-rachanabali.nltr.org/node/1414
# https://rabindra-rachanabali.nltr.org/node/1596
# end of the story
# start crolling: প্রশ্ন
# https://rabindra-rachanabali.nltr.org/node/1328
# end of the story
# start crolling: মেঘদূত
# https://rabindra-rachanabali.nltr.org/node/1278
# https://rabindra-rachanabali.nltr.org/node/1550
# end of the story
# start crolling: নতুন পুতুল
# https://rabindra-rachanabali.nltr.org/node/1425
# https://rabindra-rachanabali.nltr.org/node/1426
# https://rabindra-rachanabali.nltr.org/node/1600
# end of the story
# start crolling: কৃতঘ্ন শোক
# https://rabindra-rachanabali.nltr.org/node/1316
# end of the story
# start crolling: কথিকা
# https://rabindra-rachanabali.nltr.org/node/1532
# end of the story
# start crolling: বিদূষক
# https://rabindra-rachanabali.nltr.org/node/1362
# https://rabindra-rachanabali.nltr.org/node/1590
# end of the story
# start crolling: পুনরাবৃত্তি
# https://rabindra-rachanabali.nltr.org/node/1432
# https://rabindra-rachanabali.nltr.org/node/1437
# https://rabindra-rachanabali.nltr.org/node/1603
# https://rabindra-rachanabali.nltr.org/node/1604
# end of the story
