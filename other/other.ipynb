# %%
import os
from urllib.request import urlopen
from bs4 import BeautifulSoup

# %%
base_url = 'file:./base_html.html'
page = urlopen(base_url)

# %%
soup = BeautifulSoup(page, 'lxml')

# %%
links = {}
anchors = soup.find_all('a')
for anchor in anchors:
    links[anchor.text] = anchor['href']
len(links)
# Out:
# 4

# %%
base_url = 'https://rabindra-rachanabali.nltr.org'
for key in links.keys():
    #temporary code to avoid crolling existing file
    file_path = os.getcwd() + '/' + key + '.txt'
    if os.path.exists(file_path):
        print('exists')
        continue
    #end of temporary code
    
    print('start crolling: ' + key)
    url = base_url + links[key]
    print(url)
    text = ""
    file_name = key + '.txt'
    while True:
        page = urlopen(url)
        soup = BeautifulSoup(page, 'html.parser')
        div = soup.find('div', attrs={'class': 'upanyas'})
        if not div:
            div = soup.find('div', attrs={'class': 'node'})
        text += div.text
        # fetch next page
        right_navigation = soup.find('div', {'id': 'rightnavigation'})
        if right_navigation:
            next_page_link = right_navigation.a['href']
            url = base_url + next_page_link
            print(url)
        else:
            print('end of the story')
            break
    #end of while
    f = open(file_name,'w')
    f.write(text)
    f.close()
#end of for
# Out:
# start crolling: ইঁদুরের ভোজ
# https://rabindra-rachanabali.nltr.org/node/1705
# https://rabindra-rachanabali.nltr.org/node/1706
# end of the story
# start crolling: ললাটের লিখন
# https://rabindra-rachanabali.nltr.org/node/2206
# https://rabindra-rachanabali.nltr.org/node/2209
# https://rabindra-rachanabali.nltr.org/node/2214
# https://rabindra-rachanabali.nltr.org/node/2219
# https://rabindra-rachanabali.nltr.org/node/2223
# https://rabindra-rachanabali.nltr.org/node/2228
# https://rabindra-rachanabali.nltr.org/node/2231
# https://rabindra-rachanabali.nltr.org/node/2236
# https://rabindra-rachanabali.nltr.org/node/2241
# https://rabindra-rachanabali.nltr.org/node/2245
# https://rabindra-rachanabali.nltr.org/node/2246
# https://rabindra-rachanabali.nltr.org/node/2248
# https://rabindra-rachanabali.nltr.org/node/2251
# https://rabindra-rachanabali.nltr.org/node/2252
# https://rabindra-rachanabali.nltr.org/node/2253
# https://rabindra-rachanabali.nltr.org/node/2257
# https://rabindra-rachanabali.nltr.org/node/2264
# https://rabindra-rachanabali.nltr.org/node/2201
# https://rabindra-rachanabali.nltr.org/node/1542
# https://rabindra-rachanabali.nltr.org/node/1547
# https://rabindra-rachanabali.nltr.org/node/1552
# end of the story
# start crolling: সে
# https://rabindra-rachanabali.nltr.org/node/1727
# https://rabindra-rachanabali.nltr.org/node/1720
# https://rabindra-rachanabali.nltr.org/node/1786
# https://rabindra-rachanabali.nltr.org/node/1791
# https://rabindra-rachanabali.nltr.org/node/1794
# https://rabindra-rachanabali.nltr.org/node/1800
# https://rabindra-rachanabali.nltr.org/node/1803
# https://rabindra-rachanabali.nltr.org/node/1804
# https://rabindra-rachanabali.nltr.org/node/1809
# https://rabindra-rachanabali.nltr.org/node/1810
# https://rabindra-rachanabali.nltr.org/node/1812
# https://rabindra-rachanabali.nltr.org/node/1813
# https://rabindra-rachanabali.nltr.org/node/1816
# https://rabindra-rachanabali.nltr.org/node/1820
# https://rabindra-rachanabali.nltr.org/node/1826
# https://rabindra-rachanabali.nltr.org/node/1831
# https://rabindra-rachanabali.nltr.org/node/1850
# https://rabindra-rachanabali.nltr.org/node/1853
# https://rabindra-rachanabali.nltr.org/node/1855
# https://rabindra-rachanabali.nltr.org/node/1857
# https://rabindra-rachanabali.nltr.org/node/1868
# https://rabindra-rachanabali.nltr.org/node/1904
# https://rabindra-rachanabali.nltr.org/node/1907
